# %% [markdown]
# # Evaluate the influence of Mu on the steadu state

# %% [markdown]
# ### imports

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from network import *
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

sb.set()

# %% [markdown]
# ### Fix parameters

# %%
people = 1000
connexions = 100000
alpha = 70
steps = 10000

# %%
mu=0.05
net = Network(people,connexions,alpha, mu)
net.simulate(steps)
plt.plot(net.active_memes_count)
# Out:
# runtime : 5.33 s

# %%
mu = 0.3
net = Network(people,connexions,alpha, mu)
net.simulate(steps)
plt.plot(net.active_memes_count)
# Out:
# runtime : 4.86 s

# %%
mu = 0.5
net = Network(people,connexions,alpha, mu)
net.simulate(steps)
plt.plot(net.active_memes_count)
# Out:
# runtime : 5.02 s

# %%
mu = 0.8
net = Network(people,connexions,alpha, mu)
net.simulate(steps)
plt.plot(net.active_memes_count)
# Out:
# runtime : 5.52 s

# %%
mu = 0.99
steps = 4000
net = Network(people,connexions,alpha, mu)
net.simulate(steps)
plt.plot(net.active_memes_count)
# Out:
# runtime : 2.23 s

# %%
mu = 1
steps = 4000
net = Network(people,connexions,alpha, mu)
net.simulate(steps)
plt.plot(net.active_memes_count)
# Out:
# runtime : 2.25 s

# %% [markdown]
# Conclusion : the network indeed reaches a steady state depending on mu and alpla
